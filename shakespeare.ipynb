# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import re

# %%
df = pd.read_csv('Shakespeare_data.csv')

# %%
df
# Out:
#         Dataline            Play  PlayerLinenumber ActSceneLine  \
# 0              1        Henry IV               NaN          NaN
# 1              2        Henry IV               NaN          NaN
# 2              3        Henry IV               NaN          NaN
# 3              4        Henry IV               1.0        1.1.1
# 4              5        Henry IV               1.0        1.1.2
# 5              6        Henry IV               1.0        1.1.3
# 6              7        Henry IV               1.0        1.1.4
# 7              8        Henry IV               1.0        1.1.5
# 8              9        Henry IV               1.0        1.1.6
# 9             10        Henry IV               1.0        1.1.7
# 10            11        Henry IV               1.0        1.1.8
# 11            12        Henry IV               1.0        1.1.9
# 12            13        Henry IV               1.0       1.1.10
# 13            14        Henry IV               1.0       1.1.11
# ...

# %%
df1 = df['PlayerLine']

# %%
df1 = pd.DataFrame(df1)

# %%
df1.head()
# Out:
#                                           PlayerLine
# 0                                              ACT I
# 1                       SCENE I. London. The palace.
# 2  Enter KING HENRY, LORD JOHN OF LANCASTER, the ...
# 3             So shaken as we are, so wan with care,
# 4         Find we a time for frighted peace to pant,

# %%
import nltk

# %%
def rem_special(col):
    text=col[0]
    text=re.sub(r'[^A-Za-z0-9]+'," ",text)
    return text
df1['PlayerLine']=df1[['PlayerLine']].apply(rem_special,axis=1)

# %%
df1
# Out:
#                                                PlayerLine
# 0                                                   ACT I
# 1                              SCENE I London The palace
# 2       Enter KING HENRY LORD JOHN OF LANCASTER the EA...
# 3                   So shaken as we are so wan with care
# 4              Find we a time for frighted peace to pant
# 5          And breathe short winded accents of new broils
# 6                 To be commenced in strands afar remote
# 7               No more the thirsty entrance of this soil
# 8       Shall daub her lips with her own children s bl...
# 9        Nor more shall trenching war channel her fields
# 10          Nor bruise her flowerets with the armed hoofs
# 11                   Of hostile paces those opposed eyes
# 12           Which like the meteors of a troubled heaven
# 13               All of one nature of one substance bred
# 14                 Did lately meet in the intestine shock
# ...

# %%
def rem_dig(col):
    text=col[0]
    text=re.sub(r'\d+',"",text)
    return text
df1['PlayerLine']=df1[['PlayerLine']].apply(rem_dig,axis=1)

# %%
def con_tolower(col):
    text=col[0]
    text=text.lower()
    return text
df1['PlayerLine']=df1[['PlayerLine']].apply(con_tolower,axis=1)

# %%
df1 = df1.head(1000)

# %% [markdown]
# df1

# %%
df1.shape
# Out:
# (1000, 1)

# %%
df1
# Out:
#                                             PlayerLine
# 0                                                act i
# 1                           scene i london the palace
# 2    enter king henry lord john of lancaster the ea...
# 3                so shaken as we are so wan with care
# 4           find we a time for frighted peace to pant
# 5       and breathe short winded accents of new broils
# 6              to be commenced in strands afar remote
# 7            no more the thirsty entrance of this soil
# 8    shall daub her lips with her own children s bl...
# 9     nor more shall trenching war channel her fields
# 10       nor bruise her flowerets with the armed hoofs
# 11                of hostile paces those opposed eyes
# 12        which like the meteors of a troubled heaven
# 13            all of one nature of one substance bred
# 14              did lately meet in the intestine shock
# 15                 and furious close of civil butchery
# ...

# %%
# def splitk(col):
#     text=col[0].split()
#     return text
# df1['PlayerLine']=df1[['PlayerLine']].apply(splitk,axis=1)

# %%
df1
# Out:
#                                             PlayerLine
# 0                                                act i
# 1                           scene i london the palace
# 2    enter king henry lord john of lancaster the ea...
# 3                so shaken as we are so wan with care
# 4           find we a time for frighted peace to pant
# 5       and breathe short winded accents of new broils
# 6              to be commenced in strands afar remote
# 7            no more the thirsty entrance of this soil
# 8    shall daub her lips with her own children s bl...
# 9     nor more shall trenching war channel her fields
# 10       nor bruise her flowerets with the armed hoofs
# 11                of hostile paces those opposed eyes
# 12        which like the meteors of a troubled heaven
# 13            all of one nature of one substance bred
# 14              did lately meet in the intestine shock
# 15                 and furious close of civil butchery
# ...

# %%
from nltk.corpus import stopwords
set1=set(stopwords.words('english'))

# %%
from nltk.tokenize import word_tokenize
def stop_words1(col):
    text=col[0]
    word_tokens = word_tokenize(text)
    filtered_sentence = [w for w in word_tokens if not w in set1]
    return filtered_sentence
df1['PlayerLine']=df[['PlayerLine']].apply(stop_words1,axis=1)
# Out:
# C:\Users\Mohit\Anaconda3\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys

# %%
df1
# Out:
#                                             PlayerLine
# 0                                             [ACT, I]
# 1               [SCENE, I., London, ., The, palace, .]
# 2    [Enter, KING, HENRY, ,, LORD, JOHN, OF, LANCAS...
# 3                        [So, shaken, ,, wan, care, ,]
# 4               [Find, time, frighted, peace, pant, ,]
# 5    [And, breathe, short-winded, accents, new, bro...
# 6            [To, commenced, strands, afar, remote, .]
# 7                        [No, thirsty, entrance, soil]
# 8          [Shall, daub, lips, children, 's, blood, ,]
# 9     [Nor, shall, trenching, war, channel, fields, ,]
# 10              [Nor, bruise, flowerets, armed, hoofs]
# 11           [Of, hostile, paces, :, opposed, eyes, ,]
# 12      [Which, ,, like, meteors, troubled, heaven, ,]
# 13      [All, one, nature, ,, one, substance, bred, ,]
# 14               [Did, lately, meet, intestine, shock]
# 15              [And, furious, close, civil, butchery]
# ...

# %%
def con_tolower(col):
    text=col[0]
    for i in range(0,len(text)):
        text[i] = text[i].lower()
    return text
df1['PlayerLine']=df1[['PlayerLine']].apply(con_tolower,axis=1)
# Out:
# C:\Users\Mohit\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
def rem_special1(col):
    text=col[0]
    for i in range(0,len(text)):
        text[i]=re.sub(r'[^A-Za-z0-9]+',"",text[i])
    return text
df1['PlayerLine']=df1[['PlayerLine']].apply(rem_special1,axis=1)
# Out:
# C:\Users\Mohit\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
df1
# Out:
#                                             PlayerLine
# 0                                             [act, i]
# 1                  [scene, i, london, , the, palace, ]
# 2    [enter, king, henry, , lord, john, of, lancast...
# 3                          [so, shaken, , wan, care, ]
# 4                [find, time, frighted, peace, pant, ]
# 5    [and, breathe, shortwinded, accents, new, broils]
# 6             [to, commenced, strands, afar, remote, ]
# 7                        [no, thirsty, entrance, soil]
# 8            [shall, daub, lips, children, s, blood, ]
# 9      [nor, shall, trenching, war, channel, fields, ]
# 10              [nor, bruise, flowerets, armed, hoofs]
# 11             [of, hostile, paces, , opposed, eyes, ]
# 12        [which, , like, meteors, troubled, heaven, ]
# 13        [all, one, nature, , one, substance, bred, ]
# 14               [did, lately, meet, intestine, shock]
# 15              [and, furious, close, civil, butchery]
# ...

# %%
def rem_special1(col):
    text=col[0]
    text1=[]
    for i in range(0,len(text)-2):
        if text[i] != '':
            text1.append(text[i])
    return text1
df1['PlayerLine']=df1[['PlayerLine']].apply(rem_special1,axis=1)
# Out:
# C:\Users\Mohit\Anaconda3\lib\site-packages\ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
df1
# Out:
#                                             PlayerLine
# 0                                                   []
# 1                              [scene, i, london, the]
# 2    [enter, king, henry, lord, john, of, lancaster...
# 3                                    [so, shaken, wan]
# 4                        [find, time, frighted, peace]
# 5                 [and, breathe, shortwinded, accents]
# 6                       [to, commenced, strands, afar]
# 7                                        [no, thirsty]
# 8                     [shall, daub, lips, children, s]
# 9                [nor, shall, trenching, war, channel]
# 10                            [nor, bruise, flowerets]
# 11                       [of, hostile, paces, opposed]
# 12                    [which, like, meteors, troubled]
# 13                  [all, one, nature, one, substance]
# 14                                 [did, lately, meet]
# 15                               [and, furious, close]
# ...

# %%
dic = {}
def fn(col):
    corpus = col[0]
    #print(corpus)
    for i in range(len(corpus)-1):
        #print(corpus[i]+' '+ corpus[i+1])
        if corpus[i] in dic.keys():
            dic[corpus[i]].append(corpus[i+1])
        else:
            dic[corpus[i]] = [corpus[i+1]]

# %%
df1[['PlayerLine']].apply(fn,axis=1)
# Out:
# 0      None
# 1      None
# 2      None
# 3      None
# 4      None
# 5      None
# 6      None
# 7      None
# 8      None
# 9      None
# 10     None
# 11     None
# 12     None
# 13     None
# 14     None
# 15     None
# 16     None
# 17     None
# 18     None
# 19     None
# 20     None
# 21     None
# 22     None
# 23     None
# 24     None
# 25     None
# 26     None
# 27     None
# 28     None
# 29     None
#        ...
# 970    None
# 971    None
# 972    None
# 973    None
# 974    None
# 975    None
# 976    None
# 977    None
# 978    None
# 979    None
# 980    None
# 981    None
# 982    None
# 983    None
# 984    None
# 985    None
# 986    None
# 987    None
# 988    None
# 989    None
# 990    None
# 991    None
# 992    None
# 993    None
# 994    None
# 995    None
# 996    None
# 997    None
# 998    None
# 999    None
# Length: 1000, dtype: object

# %%
dic
# Out:
# {'scene': ['i', 'ii', 'iii', 'i', 'ii', 'iii', 'iv'],
#  'i': ['london',
#   'looking',
#   'harry',
#   'shall',
#   'sent',
#   'prithee',
#   'say',
#   'hostess',
#   'ever',
#   'll',
#   'used',
#   'prithee',
#   'o',
#   'll',
#   'mean',
#   'prithee',
#   'would',
#   'marked',
#   'knew',
#   'must',
#   'i',
#   'll',
#   'll',
#   'see',
#   'tarry',
#   'll',
#   'rob',
#   'thief',
#   'll',
#   'll',
#   'll',
#   'prithee',
#   'lay',
#   'jest',
#   'rob',
#   'doubt',
#   'll',
#   'll',
#   'know',
#   'imitate',
#   'never',
#   'falsify',
#   'll',
#   'henceforth',
#   'deny',
#   'remember',
#   'dry',
#   'smarting',
#   'answer',
#   'beseech',
#   'shall',
#   'tell',
#   'send',
#   'ease',
#   'make',
#   'speak',
#   'll',
#   'lift',
#   'blame',
#   'heard',
#   'pray',
#   'blame',
#   'descend',
#   'unclasp',
#   'll',
#   'cry',
#   'll',
#   'll',
#   's',
#   'find',
#   'll',
#   'll',
#   'solemnly',
#   'think',
#   'would',
#   'whipp',
# ...

# %%
from collections import Counter

# %%
ndic={}
for i in dic.keys():
    row=dic[i]
    c=Counter(row)
    ndic[i]=c.most_common(1)[0][0]

# %%
first='i'
s=first
i=0
while first in ndic.keys() and i < 50:
    s=s+' '+ndic[first]
    first=ndic[first]
    i=i+1
s
# Out:
# 'i ll give thee thy lantern'

# %%
first='love'
s=first
i=0
while first in ndic.keys() and i < 50:
    s=s+' '+ndic[first]
    first=ndic[first]
    i=i+1
s
# Out:
# 'love i ll give thee thy lantern'

# %%
first='london'
s=first
i=0
while first in ndic.keys() and i < 50:
    s=s+' '+ndic[first]
    first=ndic[first]
    i=i+1
s
# Out:
# 'london the thieves day gallant prize ha cousin wednesday'

# %%
for i in ndic.keys():
    s=i
    first=i
    i=0
    while first in ndic.keys() and i < 50:
        s=s+' '+ndic[first]
        first=ndic[first]
        i=i+1
    print(s)
# Out:
# scene i ll give thee thy lantern
# i ll give thee thy lantern
# london the thieves day gallant prize ha cousin wednesday
# enter prince of prisoners highness name men say men say men say men say men say men say men say men say men say men say men say men say men say men say men say men say men say men say men say men say men say men say men
# king s plains of prisoners highness name men say men say men say men say men say men say men say men say men say men say men say men say men say men say men say men say men say men say men say men say men say men say
# henry lord i ll give thee thy lantern
# lord i ll give thee thy lantern
# john of prisoners highness name men say men say men say men say men say men say men say men say men say men say men say men say men say men say men say men say men say men say men say men say men say men say men say
# ...

# %%
dic1 = {}
def fnn(col):
    corpus = col[0]
    #print(corpus)
    for i in range(len(corpus)-2):
        #print(corpus[i]+' '+ corpus[i+1])
        if (corpus[i],corpus[i+1]) in dic1.keys():
            dic1[(corpus[i],corpus[i+1])].append(corpus[i+2])
        else:
            dic1[(corpus[i],corpus[i+1])] = [corpus[i+2]]

df1[['PlayerLine']].apply(fnn,axis=1)
# Out:
# 0      None
# 1      None
# 2      None
# 3      None
# 4      None
# 5      None
# 6      None
# 7      None
# 8      None
# 9      None
# 10     None
# 11     None
# 12     None
# 13     None
# 14     None
# 15     None
# 16     None
# 17     None
# 18     None
# 19     None
# 20     None
# 21     None
# 22     None
# 23     None
# 24     None
# 25     None
# 26     None
# 27     None
# 28     None
# 29     None
#        ...
# 970    None
# 971    None
# 972    None
# 973    None
# 974    None
# 975    None
# 976    None
# 977    None
# 978    None
# 979    None
# 980    None
# 981    None
# 982    None
# 983    None
# 984    None
# 985    None
# 986    None
# 987    None
# 988    None
# 989    None
# 990    None
# 991    None
# 992    None
# 993    None
# 994    None
# 995    None
# 996    None
# 997    None
# 998    None
# 999    None
# Length: 1000, dtype: object

# %%
dic1
# Out:
# {('scene', 'i'): ['london', 'rochester'],
#  ('i', 'london'): ['the'],
#  ('enter', 'king'): ['henry', 'northumberland'],
#  ('king', 'henry'): ['lord', 'blunt'],
#  ('henry', 'lord'): ['john'],
#  ('lord', 'john'): ['of'],
#  ('john', 'of'): ['lancaster'],
#  ('of', 'lancaster'): ['earl'],
#  ('lancaster', 'earl'): ['westmoreland'],
#  ('earl', 'westmoreland'): ['sir'],
#  ('westmoreland', 'sir'): ['walter'],
#  ('sir', 'walter'): ['blunt', 'blunt', 'blunt'],
#  ('so', 'shaken'): ['wan'],
#  ('find', 'time'): ['frighted'],
#  ('time', 'frighted'): ['peace'],
#  ('and', 'breathe'): ['shortwinded'],
#  ('breathe', 'shortwinded'): ['accents'],
#  ('to', 'commenced'): ['strands'],
#  ('commenced', 'strands'): ['afar'],
#  ('shall', 'daub'): ['lips'],
#  ('daub', 'lips'): ['children'],
#  ('lips', 'children'): ['s'],
#  ('nor', 'shall'): ['trenching'],
#  ('shall', 'trenching'): ['war'],
#  ('trenching', 'war'): ['channel'],
#  ('nor', 'bruise'): ['flowerets'],
# ...

# %%
ndic1={}
for i in dic1.keys():
    row=dic1[i]
    c=Counter(row)
    ndic1[i]=c.most_common(1)[0][0]

# %%
ndic1
# Out:
# {('scene', 'i'): 'london',
#  ('i', 'london'): 'the',
#  ('enter', 'king'): 'henry',
#  ('king', 'henry'): 'lord',
#  ('henry', 'lord'): 'john',
#  ('lord', 'john'): 'of',
#  ('john', 'of'): 'lancaster',
#  ('of', 'lancaster'): 'earl',
#  ('lancaster', 'earl'): 'westmoreland',
#  ('earl', 'westmoreland'): 'sir',
#  ('westmoreland', 'sir'): 'walter',
#  ('sir', 'walter'): 'blunt',
#  ('so', 'shaken'): 'wan',
#  ('find', 'time'): 'frighted',
#  ('time', 'frighted'): 'peace',
#  ('and', 'breathe'): 'shortwinded',
#  ('breathe', 'shortwinded'): 'accents',
#  ('to', 'commenced'): 'strands',
#  ('commenced', 'strands'): 'afar',
#  ('shall', 'daub'): 'lips',
#  ('daub', 'lips'): 'children',
#  ('lips', 'children'): 's',
#  ('nor', 'shall'): 'trenching',
#  ('shall', 'trenching'): 'war',
#  ('trenching', 'war'): 'channel',
#  ('nor', 'bruise'): 'flowerets',
#  ('of', 'hostile'): 'paces',
#  ('hostile', 'paces'): 'opposed',
#  ('which', 'like'): 'meteors',
#  ('like', 'meteors'): 'troubled',
# ...

# %%
for abc in ndic1.keys():
    first=abc
    s=first[0]+' '+first[1]
    i=0
    while first in ndic1.keys() and i < 50:
        #print(first[1])
        s=s+' '+ndic1[first]
        #print(s)
        first=(first[1],ndic1[first])
        i=i+1
    print(s)
# Out:
# scene i london the
# i london the
# enter king henry lord john of lancaster earl westmoreland sir walter blunt new lighted
# king henry lord john of lancaster earl westmoreland sir walter blunt new lighted
# henry lord john of lancaster earl westmoreland sir walter blunt new lighted
# lord john of lancaster earl westmoreland sir walter blunt new lighted
# john of lancaster earl westmoreland sir walter blunt new lighted
# of lancaster earl westmoreland sir walter blunt new lighted
# lancaster earl westmoreland sir walter blunt new lighted
# earl westmoreland sir walter blunt new lighted
# westmoreland sir walter blunt new lighted
# sir walter blunt new lighted
# so shaken wan
# find time frighted peace
# time frighted peace
# and breathe shortwinded accents
# breathe shortwinded accents
# to commenced strands afar
# commenced strands afar
# shall daub lips children s
# daub lips children s
# lips children s
# nor shall trenching war channel
# shall trenching war channel
# ...

# %%
three_word={}

for abc in ndic1.keys():
    first=abc
    s=first[0]+' '+first[1]
    i=0
    while first in ndic1.keys() and i < 50:
        #print(first[1])
        if (first[0],first[1],ndic1[first]) not in three_word.keys():
            three_word[(first[0],first[1],ndic1[first])] = 0   
        #print(s)
        first=(first[1],ndic1[first])
        i=i+1

# %%
three_word
# Out:
# {('scene', 'i', 'london'): 0,
#  ('i', 'london', 'the'): 0,
#  ('enter', 'king', 'henry'): 0,
#  ('king', 'henry', 'lord'): 0,
#  ('henry', 'lord', 'john'): 0,
#  ('lord', 'john', 'of'): 0,
#  ('john', 'of', 'lancaster'): 0,
#  ('of', 'lancaster', 'earl'): 0,
#  ('lancaster', 'earl', 'westmoreland'): 0,
#  ('earl', 'westmoreland', 'sir'): 0,
#  ('westmoreland', 'sir', 'walter'): 0,
#  ('sir', 'walter', 'blunt'): 0,
#  ('walter', 'blunt', 'new'): 0,
#  ('blunt', 'new', 'lighted'): 0,
#  ('so', 'shaken', 'wan'): 0,
#  ('find', 'time', 'frighted'): 0,
#  ('time', 'frighted', 'peace'): 0,
#  ('and', 'breathe', 'shortwinded'): 0,
#  ('breathe', 'shortwinded', 'accents'): 0,
#  ('to', 'commenced', 'strands'): 0,
#  ('commenced', 'strands', 'afar'): 0,
#  ('shall', 'daub', 'lips'): 0,
#  ('daub', 'lips', 'children'): 0,
#  ('lips', 'children', 's'): 0,
#  ('nor', 'shall', 'trenching'): 0,
#  ('shall', 'trenching', 'war'): 0,
#  ('trenching', 'war', 'channel'): 0,
# ...

# %%
def three_word_fn(col):
    text = col[0]
    for i in range(0,len(text)-3):
        if (text[i],text[i+1],text[i+2]) in three_word.keys():
            three_word[(text[i],text[i+1],text[i+2])] = three_word[(text[i],text[i+1],text[i+2])]+1

# %%
df1[['PlayerLine']].apply(three_word_fn,axis=1)
# Out:
# 0      None
# 1      None
# 2      None
# 3      None
# 4      None
# 5      None
# 6      None
# 7      None
# 8      None
# 9      None
# 10     None
# 11     None
# 12     None
# 13     None
# 14     None
# 15     None
# 16     None
# 17     None
# 18     None
# 19     None
# 20     None
# 21     None
# 22     None
# 23     None
# 24     None
# 25     None
# 26     None
# 27     None
# 28     None
# 29     None
#        ...
# 970    None
# 971    None
# 972    None
# 973    None
# 974    None
# 975    None
# 976    None
# 977    None
# 978    None
# 979    None
# 980    None
# 981    None
# 982    None
# 983    None
# 984    None
# 985    None
# 986    None
# 987    None
# 988    None
# 989    None
# 990    None
# 991    None
# 992    None
# 993    None
# 994    None
# 995    None
# 996    None
# 997    None
# 998    None
# 999    None
# Length: 1000, dtype: object

# %%
three_word
# Out:
# {('scene', 'i', 'london'): 1,
#  ('i', 'london', 'the'): 0,
#  ('enter', 'king', 'henry'): 1,
#  ('king', 'henry', 'lord'): 1,
#  ('henry', 'lord', 'john'): 1,
#  ('lord', 'john', 'of'): 1,
#  ('john', 'of', 'lancaster'): 1,
#  ('of', 'lancaster', 'earl'): 1,
#  ('lancaster', 'earl', 'westmoreland'): 1,
#  ('earl', 'westmoreland', 'sir'): 1,
#  ('westmoreland', 'sir', 'walter'): 1,
#  ('sir', 'walter', 'blunt'): 1,
#  ('walter', 'blunt', 'new'): 1,
#  ('blunt', 'new', 'lighted'): 0,
#  ('so', 'shaken', 'wan'): 0,
#  ('find', 'time', 'frighted'): 1,
#  ('time', 'frighted', 'peace'): 0,
#  ('and', 'breathe', 'shortwinded'): 1,
#  ('breathe', 'shortwinded', 'accents'): 0,
#  ('to', 'commenced', 'strands'): 1,
#  ('commenced', 'strands', 'afar'): 0,
#  ('shall', 'daub', 'lips'): 1,
#  ('daub', 'lips', 'children'): 1,
#  ('lips', 'children', 's'): 0,
#  ('nor', 'shall', 'trenching'): 1,
#  ('shall', 'trenching', 'war'): 1,
#  ('trenching', 'war', 'channel'): 0,
# ...

# %%
for phrases in three_word.keys():
    if three_word[phrases]>1:
        print("{} : {}".format(phrases,three_word[phrases]))
# Out:
# ('thou', 'art', 'king') : 2
# ('sweet', 'wag', 'thou') : 2
# ('wag', 'thou', 'art') : 2
# ('by', 'lord', 'i') : 2
# ('lord', 'i', 'll') : 2
# ('i', 'll', 'give') : 2
# ('no', 'i', 'll') : 2
# ('i', 'pray', 'thee') : 2
# ('afoot', 'i', 'shall') : 2
# ('whither', 'i', 'go') : 2
